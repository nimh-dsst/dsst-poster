# %% [markdown]
# # Import required libraries

# %%
from pathlib import Path
import math
import numpy as np
import pandas as pd
from PIL import Image, ImageDraw
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import warnings

warnings.filterwarnings("ignore")
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Load in DSST Curated datasets spreadsheet
# [URL to spreadsheet](https://docs.google.com/spreadsheets/d/1t1VtW_ScMunEcrloxIv8197ezHQXCZQq_dxsSrH7SQI/edit#gid=0)

# %%
data = Path('DSST-Curated-Datasets-Public-Sheet1.tsv')
df = pd.read_csv(data, sep='\t', na_values=' ', keep_default_na=False)
df
# Out:
#      Study ID                                            Dataset  \
# 0        UKBB                                         UK Biobank
# 1        ABCD             Adolescent Brain Cognitive Development
# 2         PNC             Philadelphia Neurodevelopmental Cohort
# 3   OpenNeuro                                          OpenNeuro
# 4    OpenFMRI                                           OpenFMRI
# 5         HBN                              Healthy Brain Network
# 6        CoRR  Consortium for Reliability and Reproducabilty ...
# 7         GSP                 Brain Genomics Superstruct Project
# 8     NKI-RS   Enhanced Nathan Kline Institute - Rockland Sample
# 9        FCON                     Functional Connectomes Project
# 10        HCP             Human Connectome Project - Young Adult
# 11     ABIDE2               Autism Brain Imaging Data Exchange 2
# 12     ABIDE1               Autism Brain Imaging Data Exchange 1
# 13    ADHD200                                           ADHD-200
# 14       NILD      NIMH IRP Longitudinal Development T1w Dataset
# 15    HCP-Dev             Human Connectome Project - Development
# 16    HCP-Age                   Human Connectome Project - Aging
# 17       SLIM  Southwest U. Longitudinal Imaging Multimodal (...
# 18        SRO                           Self Regulation Ontology
# 19       dHCP                Developing Human Connectome Project
# 20        BCP                            Baby Connectome Project
# 21       SALD  Southwest University Adult Lifespan Dataset (S...
# 22      NNDSP                    NIMH/NHGRI Data Sharing Project
# 23        RAM                            Restoring Active Memory
# 24  MPI-LEMON                   Leipzig Mind-Brain-Body database
# 25      FBIRN  Functional Imaging Biomedical Informatics Rese...
# 26       MOUS                  Mother of all Unification Studies
# 27     COBRE           Center for Biomedical Research Excellence
# 28        NND                 Naturalistic Neuroimaging Database
# 29    Forrest                                       StudyForrest
# 30    HBN-SSI   Healthy Brain Network Serial Scanning Initiative
# 31        NSD                             Natural Scenes Dataset
# 32      MyCon                                      My Connectome
#
#    DSST Curation Status                          Path on NIH HPC  \
# 0            Processed         /data/Ukbb_DSST ; /data/Ukbb_proc
# 1             Processed                          /data/ABCD_DSST
# 2             Processed                       /data/DSST_dua/PNC
# 3             Processed                     /data/DSST/openneuro
# 4             Processed                      /data/DSST/Openfmri
# 5            Processed                        /data/DSST_dua/CMI
# 6            Processed                           /data/DSST/CoRR
# 7             Processed                           /data/DSST/GSP
# 8             Processed               /data/DSST/Enhanced-NKI-RS
# 9             Processed                          /data/DSST/FCON
# 10            Processed                                /data/HCP
# 11            Processed                         /data/DSST/ABIDE
# 12            Processed                        /data/DSST/ABIDE2
# 13            Processed                      /data/DSST/ADHD-200
# 14            Processed                          /data/NDAR/NILD
# 15          Not Started
# 16          Not Started
# 17            Processed                          /data/DSST/SLIM
# 18          Downloaded                            /data/DSST/SRO
# 19          Downloaded                       /data/DSST_dua/dHCP
# 20            Processed  /data/NIMH_scratch/baby-connectome/BIDS
# 21            Processed                          /data/DSST/SALD
# 22          Not Started
# 23         Not Started
# 24            Processed                     /data/DSST/MPI-LEMON
# 25          Downloaded    /data/DSST_dua/fBIRN/fBIRNPhaseII_BIDS
# 26            Processed                      /data/DSST_dua/MOUS
# 27          Downloaded           /data/DSST_dua/COBRE/COBRE_BIDS
# 28          Not Started
# 29            Processed                       /data/DSST/Forrest
# 30            Processed                       /data/DSST/HBN-SSI
# 31            Processed                   /data/NIMH_scratch/NSD
# 32          Not Started                                      NaN
#
#    Data Use Agreement Number of Subjects Sample Size  \
# 0    SIgning Official             40,000      41,500
# 1    SIgning Official             12,000      12,000
# 2    Signing Official              9,500       9,500
# 3                None              3,568       4,250
# 4                None              3,122       4,300
# 5       Click Through              2,000       2,000
# 6            Implicit              1,700       6,434
# 7            Implicit              1,500       1,500
# 8            Implicit              1,334       2,325
# 9            Implicit              1,255       6,495
# 10      Click Through              1,200       1,200
# 11           Implicit              1,114       1,152
# 12           Implicit              1,112       1,112
# 13           Implicit                800         800
# 14   Signing Official                787       1,516
# 15   Signing Official                600         600
# 16   Signing Official                600         600
# 17           Implicit                580       1,048
# 18           Implicit                522         522
# 19      Click Through                505         558
# 20   Signing Official                500         778
# 21           Implicit                500         500
# 22   Signing Official                440       1,500
# 23               Form                250         250
# 24           Implicit                228         228
# 25      Click Through                221         221
# 26      Click Through                204         204
# 27      Click Through                184         184
# 28               None                 86          86
# 29           Implicit                 20          20
# 30           Implicit                 13          13
# 31      Click Through                  8         320
# 32               None                  1         100
#
#                    Modalities Min Age Max Age Age Spread Download Date  \
# 0       anat,func,dwi,genetic      40      69         29    04/25/2020
# 1       anat,func,dwi,genetic       9      20         11    09/29/2019
# 2       anat,func,dwi,genetic       8      21         13
# 3             anat, func, dwi                               12/23/2019
# 4             anat, func, dwi                               12/23/2019
# 5   anat,func,dwi,eeg,genetic       5      21         16    10/18/2019
# 6               anat,func,dwi       6      62         56    12/23/2019
# 7                   anat,func      18      35         17    12/23/2019
# 8             anat, func, dwi       6      85         79    05/27/2020
# 9                   anat,func       7      80         73    01/10/2020
# 10          anat,func,dwi,meg      22      35         13    05/29/2019
# 11                  anat,func       5      64         59    12/23/2019
# 12              anat,func,dwi       7      64         57    12/23/2019
# 13                  anat,func       7      21         14    12/23/2019
# 14                       anat       5      25         20    10/01/2020
# 15              anat,func,dwi       5      21         16
# 16              anat,func,dwi      36     100         64
# 17              anat,func,dwi      17      24          7    12/23/2019
# 18                        beh      20      52         32       1/15/20
# 19              anat,func,dwi   -0.75    -0.2       0.55    12/01/2022
# 20              anat,func,dwi       0       7          7    12/01/2022
# 21                  anat,func      19      80         61    12/23/2019
# 22                  anat,func       5      77         72       1/15/20
# 23                  anat,ecog
# 24   anat,func,dwi,eeg,physio      20      77         57     8/18/2020
# 25                 anat, func      19      65         46    02/23/2021
# 26          anat,func,dwi,meg      18      33         15     10/3/2019
# 27             anat, func,beh      18      66         48    02/19/2021
# 28                  anat,func      18      58         40
# 29              anat,func,dwi      20      35         15    12/23/2019
# 30              anat,func,dwi      21      42         21    12/23/2019
# 31                  anat,func      19      32         13    09/07/2021
# 32          anat,func,genetic      45      46          1
#
#    Current Release Date Initial Release Date  \
# 0              10/01/15           09/01/2019
# 1              03/26/19           06/28/2017
# 2            02/27/2017           07/12/2012
# 3
# 4
# 5            09/17/2019           06/14/2017
# 6            12/09/2014           12/09/2014
# 7                                 12/12/2012
# 8            02/08/2019           10/16/2012
# 9            12/23/2009           10/12/2009
# 10           07/21/2017           05/03/2013
# 11           03/27/2017           09/25/2016
# 12           12/23/2011           12/23/2011
# 13           01/07/2011           01/07/2011
# 14           06/15/2018           06/15/2018
# 15           05/21/2019           05/21/2019
# 16           05/21/2019           05/21/2019
# 17           02/14/2017           07/11/2014
# 18           02/16/2019           12/05/2017
# 19           01/21/2019           06/23/2015
# 20           11/15/2019           07/15/2019
# 21           01/29/2018           01/29/2018
# 22           12/05/2017           12/05/2017
# 23           05/27/2019           11/11/2016
# 24           02/12/2019           02/12/2019
# 25           10/18/2008           03/05/2008
# 26           02/20/2019           11/15/2016
# 27           06/08/2021           01/19/2015
# 28           05/22/2020           05/22/2020
# 29           06/29/2015           01/27/2014
# 30           01/07/2017           01/07/2017
# 31           09/03/2021           09/03/2021
# 32           07/18/2018           08/05/2015
#
#                                            func tasks  \
# 0                                 rest,emotion,vision
# 1   rest,reward,executive function,emotion,working...
# 2                         rest,emotion,working memory
# 3                                            multiple
# 4                                            multiple
# 5                                          rest,movie
# 6                                                rest
# 7                                                rest
# 8              rest, visual checkerboard, breath hold
# 9                                                rest
# 10  rest,emotion,language,motor,relational,social,...
# 11                                               rest
# 12                                               rest
# 13                                               rest
# 14                                                N/A
# 15             rest,reward,executive function,emotion
# 16            rest,vismotor,executive function,memory
# 17                                               rest
# 18                                                N/A
# 19                                               rest
# 20                                               rest
# 21                                               rest
# 22                                               rest
# 23                            verbal,learning,spatial
# 24                                               rest
# 25                     rest, auditory oddball, memory
# 26                                      rest,language
# 27                                               rest
# 28                                              movie
# 29                        movie,auditory,music,visual
# 30                        rest,movie,inscapes,flanker
# 31                                             visual
# 32                                rest,working memory
#
#                                              Comments  \
# 0   Eventually 100,000 subjects with genetics, 1.5...
# 1   Eventually longitidinal following 10k adolesce...
# 2   Participants with diverse medical conditions: ...
# 3   Repsitory of multiple (and typically smaller) ...
# 4   Repsitory of multiple (and typically smaller) ...
# 5   Goal of 10k children with a variety of concern...
# 6   Large sample across multiple sites to facilita...
# 7                   One or more rest scan per subject
# 8
# 9   Collected across 33 different sites, basic phe...
# 10  3 hrs, subsample at 7T, twins &siblings, multi...
# 11           ASD and neurotypical from multiple sites
# 12           ASD and neurotypical from multiple sites
# 13          ADHD and neurotypical from multiple sites
# 14                     Longitudinal structural sample
# 15            Large neurotypical developmental sample
# 16  Wide age range, study goal of 300 subjects wit...
# 17  Large multimodal sample of a southwestern chin...
# 18                   Extensive behavioral phenotyping
# 19                                   In utero imaging
# 20                   Longitudinal and cross-secitonal
# 21                                     Wide age range
# 22  Large development sample of structural images,...
# 23      Intracranial recordings during multiple tasks
# 24           2 age groups: young/old, physio for fMRI
# 25  Cinical dataset with patients with schizophren...
# 26                   Multimodal within the same tasks
# 27  Cinical dataset with patients with schizophren...
# 28     86 subjects watching entirty of 1 of 10 movies
# 29         Extensive hi res multimodal imaging sample
# 30  13 subjects over 12 sessions with repeated sti...
# 31                                                 7T
# 32      Highly sampled imaging on a single individual
#
#                                           Publication  \
# 0             https://www.nature.com/articles/nn.4393
# 1               https://doi.org/10.1093/cercor/bhz257
# 2                    10.1016/j.neuroimage.2013.07.064
# 3
# 4
# 5        https://www.nature.com/articles/sdata2017181
# 6         https://www.nature.com/articles/sdata201449
# 7         https://www.nature.com/articles/sdata201531
# 8           https://pubmed.ncbi.nlm.nih.gov/23087608/
# 9        https://www.ncbi.nlm.nih.gov/pubmed/20176931
# 10   https://doi.org/10.1016/j.neuroimage.2018.01.018
# 11              https://doi.org/10.1038/sdata.2017.10
# 12                           10.3389/fninf.2011.00033
# 13   https://doi.org/10.1016/j.neuroimage.2016.06.034
# 14  https://science.sciencemag.org/content/360/639...
# 15   https://doi.org/10.1016/j.neuroimage.2018.09.060
# 16       https://www.ncbi.nlm.nih.gov/pubmed/30332613
# 17        https://www.nature.com/articles/sdata201717
# 18  https://www.nature.com/articles/s41467-019-103...
# 19   https://doi.org/10.1016/j.neuroimage.2019.116137
# 20          https://pubmed.ncbi.nlm.nih.gov/29578031/
# 21   https://www.biorxiv.org/content/10.1101/177279v2
# 22                  https://doi.org/10.1002/hbm.23911
# 23  https://www.nature.com/articles/s41551-019-0404-5
# 24       https://www.nature.com/articles/sdata2018308
# 25  https://link.springer.com/article/10.1007/s120...
# 26  https://www.nature.com/articles/s41597-019-0020-y
# 27       https://www.ncbi.nlm.nih.gov/pubmed/28812221
# 28  https://www.biorxiv.org/content/10.1101/2020.0...
# 29         https://www.nature.com/articles/sdata20143
# 30  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...
# 31  https://www.nature.com/articles/s41593-021-009...
# 32         https://www.nature.com/articles/ncomms9885
#
#                                          Dataset Name  \
# 0                                          UK Biobank
# 1              Adolescent Brain Cognitive Development
# 2              Philadelphia Neurodevelopmental Cohort
# 3                                           OpenNeuro
# 4                                            OpenFMRI
# 5                               Healthy Brain Network
# 6   Consortium for Reliability and Reproducabilty ...
# 7                  Brain Genomics Superstruct Project
# 8   Enhanced Nathan Kline Institute - Rockland Sample
# 9                      Functional Connectomes Project
# 10             Human Connectome Project - Young Adult
# 11               Autism Brain Imaging Data Exchange 2
# 12               Autism Brain Imaging Data Exchange 1
# 13                                           ADHD-200
# 14      NIMH IRP Longitudinal Development T1w Dataset
# 15             Human Connectome Project - Development
# 16                   Human Connectome Project - Aging
# 17  Southwest U. Longitudinal Imaging Multimodal (...
# 18                           Self Regulation Ontology
# 19                Developing Human Connectome Project
# 20                            Baby Connectome Project
# 21  Southwest University Adult Lifespan Dataset (S...
# 22                    NIMH/NHGRI Data Sharing Project
# 23                            Restoring Active Memory
# 24                   Leipzig Mind-Brain-Body database
# 25  Functional Imaging Biomedical Informatics Rese...
# 26                  Mother of all Unification Studies
# 27          Center for Biomedical Research Excellence
# 28                 Naturalistic Neuroimaging Database
# 29                                       StudyForrest
# 30   Healthy Brain Network Serial Scanning Initiative
# 31                             Natural Scenes Dataset
# 32                                      My Connectome
#
#                                          Dataset Link
# 0                        https://www.ukbiobank.ac.uk/
# 1                        https://abcdstudy.org/about/
# 2   https://www.med.upenn.edu/bbl/philadelphianeur...
# 3                                http://openneuro.org
# 4                               https://openfmri.org/
# 5   http://fcon_1000.projects.nitrc.org/indi/cmi_h...
# 6   http://fcon_1000.projects.nitrc.org/indi/CoRR/...
# 7                      https://www.neuroinfo.org/gsp/
# 8   https://fcon_1000.projects.nitrc.org/indi/enha...
# 9   http://fcon_1000.projects.nitrc.org/fcpClassic...
# 10  https://www.humanconnectome.org/study/hcp-youn...
# 11  http://fcon_1000.projects.nitrc.org/indi/abide...
# 12  http://fcon_1000.projects.nitrc.org/indi/abide...
# 13  http://fcon_1000.projects.nitrc.org/indi/adhd2...
# 14                 http://dx.doi.org/10.15154/1504177
# 15  https://www.humanconnectome.org/study/hcp-life...
# 16  https://www.humanconnectome.org/study/hcp-life...
# 17  http://fcon_1000.projects.nitrc.org/indi/retro...
# 18  https://www.nature.com/articles/s41467-019-103...
# 19  http://www.developingconnectome.org/second-dat...
# 20   https://nda.nih.gov/edit_collection.html?id=2848
# 21  http://fcon_1000.projects.nitrc.org/indi/retro...
# 22                 http://dx.doi.org/10.15154/1463004
# 23      http://memory.psych.upenn.edu/RAM_Public_Data
# 24  http://fcon_1000.projects.nitrc.org/indi/retro...
# 25              https://www.nitrc.org/projects/fbirn/
# 26  https://data.donders.ru.nl/collections/di/dccn...
# 27                              http://coins.mrn.org/
# 28  https://openneuro.org/datasets/ds002837/versio...
# 29                           http://studyforrest.org/
# 30  http://fcon_1000.projects.nitrc.org/indi/hbn_ssi/
# 31                   http://naturalscenesdataset.org/
# 32      http://myconnectome.org/wp/about-the-project/

# %% [markdown]
# # Creating a mask for desired wordcloud shape

# %%
# word cloud shape mask
head_mask = np.array(Image.open('head.png'))

# %% [markdown]
# # WordCloud 1: Dataset & Sample Size

# %%
sub_df = df[['Dataset', 'Sample Size']]
for i, v in sub_df['Sample Size'].items():
    # converting from python object to int and then applying log base 2
    sub_df.at[i, 'Sample Size'] = round(math.log(int(str(v).replace(',', '')), 2), 3)

# %%
sub_df
# Out:
#                                               Dataset Sample Size
# 0                                          UK Biobank      15.341
# 1              Adolescent Brain Cognitive Development      13.551
# 2              Philadelphia Neurodevelopmental Cohort      13.214
# 3                                           OpenNeuro      12.053
# 4                                            OpenFMRI       12.07
# 5                               Healthy Brain Network      10.966
# 6   Consortium for Reliability and Reproducabilty ...      12.652
# 7                  Brain Genomics Superstruct Project      10.551
# 8   Enhanced Nathan Kline Institute - Rockland Sample      11.183
# 9                      Functional Connectomes Project      12.665
# 10             Human Connectome Project - Young Adult      10.229
# 11               Autism Brain Imaging Data Exchange 2       10.17
# 12               Autism Brain Imaging Data Exchange 1      10.119
# 13                                           ADHD-200       9.644
# 14      NIMH IRP Longitudinal Development T1w Dataset      10.566
# 15             Human Connectome Project - Development       9.229
# 16                   Human Connectome Project - Aging       9.229
# 17  Southwest U. Longitudinal Imaging Multimodal (...      10.033
# 18                           Self Regulation Ontology       9.028
# 19                Developing Human Connectome Project       9.124
# 20                            Baby Connectome Project       9.604
# 21  Southwest University Adult Lifespan Dataset (S...       8.966
# 22                    NIMH/NHGRI Data Sharing Project      10.551
# 23                            Restoring Active Memory       7.966
# 24                   Leipzig Mind-Brain-Body database       7.833
# 25  Functional Imaging Biomedical Informatics Rese...       7.788
# 26                  Mother of all Unification Studies       7.672
# 27          Center for Biomedical Research Excellence       7.524
# 28                 Naturalistic Neuroimaging Database       6.426
# 29                                       StudyForrest       4.322
# 30   Healthy Brain Network Serial Scanning Initiative         3.7
# 31                             Natural Scenes Dataset       8.322
# 32                                      My Connectome       6.644

# %%
# creating a dictionary with dataset name as key and sample size (log scale base 2) as value
dataset_sample_size = dict(zip(sub_df['Dataset'].tolist(), sub_df['Sample Size'].tolist()))
dataset_sample_size
# Out:
# {'UK Biobank': 15.341,
#  'Adolescent Brain Cognitive Development': 13.551,
#  'Philadelphia Neurodevelopmental Cohort': 13.214,
#  'OpenNeuro': 12.053,
#  'OpenFMRI': 12.07,
#  'Healthy Brain Network': 10.966,
#  'Consortium for Reliability and Reproducabilty (CoRR)': 12.652,
#  'Brain Genomics Superstruct Project': 10.551,
#  'Enhanced Nathan Kline Institute - Rockland Sample': 11.183,
#  'Functional Connectomes Project': 12.665,
#  'Human Connectome Project - Young Adult': 10.229,
#  'Autism Brain Imaging Data Exchange 2': 10.17,
#  'Autism Brain Imaging Data Exchange 1': 10.119,
#  'ADHD-200': 9.644,
#  'NIMH IRP Longitudinal Development T1w Dataset': 10.566,
#  'Human Connectome Project - Development': 9.229,
#  'Human Connectome Project - Aging': 9.229,
#  'Southwest U. Longitudinal Imaging Multimodal (SLIM)': 10.033,
#  'Self Regulation Ontology': 9.028,
#  'Developing Human Connectome Project': 9.124,
#  'Baby Connectome Project': 9.604,
#  'Southwest University Adult Lifespan Dataset (SALD)': 8.966,
#  'NIMH/NHGRI Data Sharing Project': 10.551,
#  'Restoring Active Memory': 7.966,
#  'Leipzig Mind-Brain-Body database': 7.833,
#  'Functional Imaging Biomedical Informatics Research Network (BIRN)': 7.788,
#  'Mother of all Unification Studies': 7.672,
#  'Center for Biomedical Research Excellence': 7.524,
#  'Naturalistic Neuroimaging Database': 6.426,
#  'StudyForrest': 4.322,
#  'Healthy Brain Network Serial Scanning Initiative': 3.7,
#  'Natural Scenes Dataset': 8.322,
#  'My Connectome': 6.644}

# %%
# White background
wc1_whitebg = WordCloud(background_color='white', scale=2, colormap='hsv', contour_color='black', contour_width=5,
                        mask=head_mask).generate_from_frequencies(dataset_sample_size)

plt.figure(figsize=(25, 25))
plt.imshow(wc1_whitebg, interpolation='bilinear')
plt.axis('off')
plt.show()

wc1_whitebg.to_file("wordclouds/dataset_sampleSize_whitebg_logscale.png")  # saving to file

# %%
# Black background
wc1_blackbg = WordCloud(background_color='black', scale=2, colormap='hsv', contour_color='lightgrey', contour_width=5,
                        mask=head_mask).generate_from_frequencies(dataset_sample_size)

plt.figure(figsize=(25, 25))
plt.imshow(wc1_blackbg, interpolation='bilinear')
plt.axis('off')
plt.show()

wc1_blackbg.to_file("wordclouds/dataset_sampleSize_blackbg_logscale.png")  # saving to file

# %% [markdown]
# # Word Cloud 2: Modality frequencies

# %%
# creating frequency count dictionary
modality_counts = dict()
for idx, mod_str in df['Modalities'].items():
    mod_list = mod_str.split(',')
    for mod in mod_list:
        if mod.strip() not in modality_counts.keys():
            modality_counts[mod.strip()] = 1
        else:
            modality_counts[mod.strip()] += 1
print(modality_counts)
# Out:
# {'anat': 32, 'func': 30, 'dwi': 19, 'genetic': 5, 'eeg': 2, 'meg': 2, 'beh': 2, 'ecog': 1, 'physio': 1}

# %%
# White background
wc2_whitebg = WordCloud(background_color='white', scale=2, colormap='hsv', contour_color='black', contour_width=5,
                        mask=head_mask).generate_from_frequencies(modality_counts)

plt.figure(figsize=(25, 25))
plt.imshow(wc2_whitebg, interpolation='bilinear')
plt.axis('off')
plt.show()

wc2_whitebg.to_file("wordclouds/modality_freq_whitebg.png")

# %%
# Black background
wc2_blackbg = WordCloud(background_color='black', scale=2, colormap='hsv', contour_color='lightgrey', contour_width=5,
                        mask=head_mask).generate_from_frequencies(modality_counts)

plt.figure(figsize=(25, 25))
plt.imshow(wc2_blackbg, interpolation='bilinear')
plt.axis('off')
plt.show()

wc2_blackbg.to_file("wordclouds/modality_freq_blackbg.png")  # saving to file

# %% [markdown]
# # WordCloud 3: Study ID & Sample Size

# %%
studyid_samplesize = dict(zip(df['Study ID'].tolist(), sub_df['Sample Size'].tolist()))
studyid_samplesize
# Out:
# {'UKBB': 15.341,
#  'ABCD': 13.551,
#  'PNC': 13.214,
#  'OpenNeuro': 12.053,
#  'OpenFMRI': 12.07,
#  'HBN': 10.966,
#  'CoRR': 12.652,
#  'GSP': 10.551,
#  'NKI-RS ': 11.183,
#  'FCON': 12.665,
#  'HCP': 10.229,
#  'ABIDE2': 10.17,
#  'ABIDE1': 10.119,
#  'ADHD200': 9.644,
#  'NILD': 10.566,
#  'HCP-Dev': 9.229,
#  'HCP-Age': 9.229,
#  'SLIM': 10.033,
#  'SRO': 9.028,
#  'dHCP': 9.124,
#  'BCP': 9.604,
#  'SALD': 8.966,
#  'NNDSP': 10.551,
#  'RAM': 7.966,
#  'MPI-LEMON': 7.833,
#  'FBIRN': 7.788,
#  'MOUS': 7.672,
#  'COBRE ': 7.524,
#  'NND': 6.426,
#  'Forrest': 4.322,
#  'HBN-SSI': 3.7,
#  'NSD': 8.322,
#  'MyCon': 6.644}

# %%
# wordcloud in white bg
wc3_whitebg = WordCloud(background_color='white', scale=2, colormap='hsv', contour_color='black', contour_width=5,
                        mask=head_mask).generate_from_frequencies(studyid_samplesize)
plt.figure(figsize=(25, 25))
plt.imshow(wc3_whitebg, interpolation='bilinear')
plt.axis('off')
plt.show()

wc3_whitebg.to_file('wordclouds/studyid_sampleSize_whitebg_logscale.png')  # saving to file

# %%
# wordcloud in black bg
wc3_blackbg = WordCloud(background_color='black', scale=2, colormap='hsv', contour_color='lightgrey', contour_width=5,
                        mask=head_mask).generate_from_frequencies(studyid_samplesize)
plt.figure(figsize=(25, 25))
plt.imshow(wc3_blackbg, interpolation='bilinear')
plt.axis('off')
plt.show()

wc3_blackbg.to_file('wordclouds/studyid_sampleSize_blackbg_logscale.png')  # saving to file
